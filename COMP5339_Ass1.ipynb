# %%
# !pip install googlemaps tqdm
# Out:
# Collecting googlemaps
#   Downloading googlemaps-4.10.0.tar.gz (33 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: tqdm in c:\anaconda\lib\site-packages (4.67.0)
# Requirement already satisfied: requests<3.0,>=2.20.0 in c:\anaconda\lib\site-packages (from googlemaps) (2.32.3)
# Requirement already satisfied: colorama in c:\anaconda\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2025.1.31)
# Building wheels for collected packages: googlemaps
#   Building wheel for googlemaps (setup.py): started
#   Building wheel for googlemaps (setup.py): finished with status 'done'
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40746 sha256=5b52a6183fbea8df1b6a576fa71853e87fdaf7776709606b41548046a21982a2
#   Stored in directory: c:\users\susan\appdata\local\pip\cache\wheels\f1\09\77\3cc2f5659cbc62341b30f806aca2b25e6a26c351daa5b1f49a
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.10.0

# %%
import pandas as pd
import numpy as np
import requests
import time
import googlemaps
from tqdm.notebook import tqdm

# %%
files = [
    "NGER.ID0075.csv", "NGER.ID0076.csv", "NGER.ID0077.csv",
    "NGER.ID0078.csv", "NGER.ID0079.csv", "NGER.ID0080.csv",
    "NGER.ID0081.csv", "NGER.ID0082.csv", "NGER.ID0083.csv",
    "NGER.ID0243.csv"
]

# standardize columns
ref = pd.read_csv("NGER.ID0243.csv")
standard_cols = ref.columns.tolist()
print("standard columns：", standard_cols)

dfs = []

for fname in files:
    df = pd.read_csv(fname)

    # normalize field names
    rename_map = {}
    for c in df.columns:
        c_clean = c.strip().lower().replace(" ", "_")
        for std in standard_cols:
            std_clean = std.strip().lower().replace(" ", "_")
            if c_clean == std_clean:
                rename_map[c] = std
    df = df.rename(columns = rename_map)

    # fill in missing fields
    for col in standard_cols:
        if col not in df.columns:
            df[col] = pd.NA

    # keep standard columns only
    df = df[standard_cols]

    dfs.append(df)

# vertical merge
NGER = pd.concat(dfs, ignore_index=True, sort=False)
print("combined size：", NGER.shape)
# Out:
# standard columns： ['Reporting entity', 'Facility name', 'Type', 'State', 'Electricity production GJ', 'Electricity production MWh', 'Total scope 1 emissions t CO2 e', 'Total scope 2 emissions t CO2 e', 'Total emissions t CO2 e', 'Emission intensity t CO2 e MWh', 'Grid connected', 'Grid', 'Primary fuel', 'Important notes']
# combined size： (5942, 14)
# C:\Users\susan\AppData\Local\Temp\ipykernel_14416\1153108482.py:39: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   NGER = pd.concat(dfs, ignore_index=True, sort=False)

# %%
# drop unnecessary row
NGER = NGER[NGER["Facility name"] != "Corporate Total"]
NGER = NGER.drop(NGER[NGER["Type"].isna()].index)
NGER = NGER.drop(NGER[NGER["Type"] == "-"].index)
NGER = NGER.drop(NGER[NGER["Electricity production GJ"].isna()].index)

# %%
# handle missing value in CO2 Emissions by median
for col in ["Total scope 1 emissions t CO2 e", "Total scope 2 emissions t CO2 e"]:
    NGER[col] = NGER[col].fillna(NGER[col].median())

# %%
# Calculate Emission Intensity
mask = NGER["Emission intensity t CO2 e MWh"].isna() & \
       (NGER["Electricity production MWh"] > 0)
NGER.loc[mask, "Emission intensity t CO2 e MWh"] = (
    NGER.loc[mask, "Total emissions t CO2 e"] /
    NGER.loc[mask, "Electricity production MWh"]
)

# %%
# handle Grid column
NGER["Grid connected"] = NGER["Grid connected"].fillna("Off").replace("-", "Off")
NGER["Grid"] = NGER["Grid"].fillna("Off-grid").replace("-", "Off-grid")

# %%
# drop unecessary column
NGER = NGER.drop(columns=["Important notes"], errors="ignore")

# %%
# type transform
cat_cols = ['Reporting entity','Facility name','Type','State',
            'Grid connected','Grid','Primary fuel']
for col in cat_cols:
    NGER[col] = NGER[col].astype('category')

# %%
print(NGER.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4877 entries, 0 to 5940
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Reporting entity                 4476 non-null   category
#  1   Facility name                    4877 non-null   category
#  2   Type                             4877 non-null   category
#  3   State                            4877 non-null   category
#  4   Electricity production GJ        4877 non-null   float64
#  5   Electricity production MWh       4877 non-null   float64
#  6   Total scope 1 emissions t CO2 e  4877 non-null   float64
#  7   Total scope 2 emissions t CO2 e  4877 non-null   float64
#  8   Total emissions t CO2 e          4877 non-null   int64
#  9   Emission intensity t CO2 e MWh   4877 non-null   float64
#  10  Grid connected                   4877 non-null   category
#  11  Grid                             4877 non-null   category
#  12  Primary fuel                     4877 non-null   category
# dtypes: category(7), float64(5), int64(1)
# memory usage: 360.6 KB
# None

# %%
NGER.nunique()
# Out:
# Reporting entity                    314
# Facility name                       853
# Type                                  2
# State                                 8
# Electricity production GJ          4699
# Electricity production MWh         4519
# Total scope 1 emissions t CO2 e    2543
# Total scope 2 emissions t CO2 e    1156
# Total emissions t CO2 e            3003
# Emission intensity t CO2 e MWh     1272
# Grid connected                        2
# Grid                                  6
# Primary fuel                         22
# dtype: int64

# %%
ac = pd.read_csv("power-stations-and-projects-accredited.csv")
cm = pd.read_csv("power-stations-and-projects-committed.csv")
pr = pd.read_csv("power-stations-and-projects-probable.csv")

# %%
print("accredited columns:", ac.columns.tolist())
print("committed  columns:", cm.columns.tolist())
print("probable   columns:", pr.columns.tolist())
# Out:
# accredited columns: ['Accreditation code', 'Power station name', 'State', 'Postcode', 'Installed capacity (MW)', 'Fuel Source (s)', 'Accreditation start date', 'Approval date']
# committed  columns: ['Project Name', 'State ', 'MW Capacity', 'Fuel Source', 'Committed Date (Month/Year)']
# probable   columns: ['Project Name', 'State ', 'MW Capacity', 'Fuel Source']

# %%
# standardize column names
ac_core = ac.rename(columns={
    "Power station name": "Project Name",
    "Installed capacity (MW)": "MW Capacity",
    "Fuel Source (s)": "Fuel Source",
    "State": "State"
})[["Project Name","State","MW Capacity","Fuel Source"]]

cm_core = cm.rename(columns={"State ": "State"})[["Project Name","State","MW Capacity","Fuel Source"]]
pr_core = pr.rename(columns={"State ": "State"})[["Project Name","State","MW Capacity","Fuel Source"]]

# add status column
ac_core["status"] = "accredited"
cm_core["status"] = "committed"
pr_core["status"] = "probable"

# combined
core_summary = pd.concat([ac_core, cm_core, pr_core], ignore_index=True)

# remove space
core_summary = core_summary.apply(lambda x: x.str.strip() if x.dtype=="object" else x)

# Project Name standardize
core_summary["Project Name"] = (
    core_summary["Project Name"]
    .str.split("-").str[0]
    .str.strip()
)

print("core_summary shape:", core_summary.shape)
print(core_summary.head())
# Out:
# core_summary shape: (365, 5)
#                       Project Name State  MW Capacity Fuel Source      status
# 0     Laura Johnson Home, Townview   QLD       0.2265       Solar  accredited
# 1                       Leppington   NSW       0.7320       Solar  accredited
# 2  Quakers Hillside Care Community   NSW       0.1996       Solar  accredited
# 3                    Rest Nominees   VIC       0.1188       Solar  accredited
# 4          Retail First Mt Ommaney   QLD       1.0004       Solar  accredited

# %%
renewable_accredited_detail = ac.copy()
renewable_committed_detail  = cm.copy()
renewable_probable_detail   = pr.copy()

core_summary.to_csv("core_summary.csv", index=False)
renewable_accredited_detail.to_csv("accredited_detail.csv", index=False)
renewable_committed_detail.to_csv("committed_detail.csv", index=False)
renewable_probable_detail.to_csv("probable_detail.csv", index=False)

# %%
print(core_summary.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Project Name  365 non-null    object
#  1   State         365 non-null    object
#  2   MW Capacity   365 non-null    float64
#  3   Fuel Source   365 non-null    object
#  4   status        365 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 14.4+ KB
# None

# %%
# data augmentation
gmaps = googlemaps.Client(key="AIzaSyAl7LWzK05ZLBkzDAyonAj5OSew3IwV_1E")

def get_coordinates_google(address):
    try:
        geocode_result = gmaps.geocode(address)
        if geocode_result:
            location = geocode_result[0]['geometry']['location']
            return location['lat'], location['lng']
    except Exception as e:
        print(f"Error on {address}: {e}")
    return None, None

# %%
sample = core_summary.head(10)

for i, row in sample.iterrows():
    addr = f"{row['Project Name']}, {row['State']}, Australia"
    lat, lon = get_coordinates_google(addr)
    print(f"{i}: {addr} -> ({lat}, {lon})")
    time.sleep(0.5)
# Out:
# 0: Laura Johnson Home, Townview, QLD, Australia -> (-20.7342326, 139.5034862)
# 1: Leppington, NSW, Australia -> (-33.9773022, 150.7834354)
# 2: Quakers Hillside Care Community, NSW, Australia -> (-33.719511, 150.891607)
# 3: Rest Nominees, VIC, Australia -> (-36.9847807, 143.3906074)
# 4: Retail First Mt Ommaney, QLD, Australia -> (-27.5452429, 152.9319813)
# 5: Woolworths HCFDC Heathwood, QLD, Australia -> (-27.6348312, 152.9917087)
# 6: Woolworths Kings Meadow 7210, TAS, Australia -> (-41.464775, 147.1601562)
# 7: CLAYTON CHURCH HOMES INC, SA, Australia -> (-30.0002315, 136.2091547)
# 8: Dalwood Children's Home, NSW, Australia -> (-32.6274801, 151.4200826)
# 9: Haighs Proprietary Limited, SA, Australia -> (-30.0002315, 136.2091547)

# %%
latitudes = []
longitudes = []

for addr in tqdm(core_summary["Project Name"] + ", " + core_summary["State"] + ", Australia",
                 desc="Google Geocoding", unit="site"):
    lat, lon = get_coordinates_google(addr)
    latitudes.append(lat)
    longitudes.append(lon)
    time.sleep(0.2)

core_summary["latitude"] = latitudes
core_summary["longitude"] = longitudes
# Out:
# Google Geocoding:   0%|          | 0/365 [00:00<?, ?site/s]

# %%
print((core_summary["latitude"].notna().mean()*100).round(2), "% success rate")
core_summary.to_csv("core_summary_with_google_coords.csv", index=False)
# Out:
# 100.0 % success rate

# %%
pop_df1 = pd.read_excel("14100DO0003_2011-24.xlsx", sheet_name = "Table 1", 
                        skiprows=5, header=[0,1], index_col=[0,1,2], na_values=['-']);
pop_df2 = pd.read_excel("14100DO0003_2011-24.xlsx", sheet_name = "Table 2", 
                        skiprows=5, header=[0,1], index_col=[0,1,2], na_values=['-']);

# %%
#breaking every multiheader table into smaller dataframes.
def table_concatenation(pop_df1, pop_df2):
    sub_tables = {}
    top_headers_df1 = pop_df1.columns.get_level_values(0).unique()
    top_headers_df2 = pop_df2.columns.get_level_values(0).unique()
    for header in top_headers_df1:
        sub_df1 = pop_df1.xs(header, axis=1, level=0)
        if header in top_headers_df2:
            sub_df2 = pop_df2.xs(header, axis=1, level=0)
            sub_tables[header] = pd.concat([sub_df1, sub_df2])
        else:
            sub_tables[header] = sub_df1
    for header in top_headers_df2:
        if header not in sub_tables:
            sub_tables[header] = pop_df2.xs(header, axis=1, level=0)
    return sub_tables

# %%
def economy_table_cleaning(tables):
    try:
        headers = list(tables.keys())
        for header in headers:
            df = tables[header].copy()
            df = df.dropna(how='all') #removing all rows that are completely nan for each sub tables
            df.reset_index(inplace=True)
            df.set_index(['level_0', 'level_1'], inplace=True)
            df.rename(columns={'level_2': 'Year'}, inplace=True)
            df.rename_axis(index={'level_0':'Code', 'level_1':'Region'}, inplace=True)

            #replacing nan values of rows that are not completely nan with the median of that column for a particular region+code
            df = df.groupby(level=['Code', 'Region']).transform(
                lambda x:x.fillna(x.mean() if not np.isnan(x.median()) else 0)
            )
            df.reset_index(inplace=True)
            for col in df.columns:
                if '(no.)' in col or 'number' in col or 'Number' in col:
                    df[col] = df[col].astype('int64')
            tables[header] = df
             
    except Exception as e:
            print("Data is either already cleaned/invalid")
            
    return tables

# %%
sub_tables = table_concatenation(pop_df1[:29090], pop_df2[:5472])

# %%
sub_tables = economy_table_cleaning(sub_tables)

# %%
for header in headers[:-1]:
    print(header)
    print(sub_tables[header].info())

print("Power Station location")
print(core_summary.info())

print("Other energy sources")
print(NGER.info())
# Out:
# Number of businesses - at 30 June
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17015 entries, 0 to 17014
# Data columns (total 8 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Code                                                  17015 non-null  object
#  1   Region                                                17015 non-null  object
#  2   Year                                                  17015 non-null  int64
#  3   Number of non-employing businesses                    17015 non-null  int64
#  4   Number of employing businesses: 1-4 employees         17015 non-null  int64
#  5   Number of employing businesses: 5-19 employees        17015 non-null  int64
#  6   Number of employing businesses: 20 or more employees  17015 non-null  int64
#  7   Total number of businesses                            17015 non-null  int64
# dtypes: int64(6), object(2)
# memory usage: 1.0+ MB
# None
# Business entries - year ended 30 June
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13422 entries, 0 to 13421
# Data columns (total 8 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Code                                                        13422 non-null  object
#  1   Region                                                      13422 non-null  object
#  2   Year                                                        13422 non-null  int64
#  3   Number of non-employing business entries                    13422 non-null  int64
#  4   Number of employing business entries: 1-4 employees         13422 non-null  int64
#  5   Number of employing business entries: 5-19 employees        13422 non-null  int64
#  6   Number of employing business entries: 20 or more employees  13422 non-null  int64
#  7   Total number of business entries                            13422 non-null  int64
# dtypes: int64(6), object(2)
# memory usage: 839.0+ KB
# None
# Business exits - year ended 30 June
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13408 entries, 0 to 13407
# Data columns (total 8 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Code                                                      13408 non-null  object
#  1   Region                                                    13408 non-null  object
#  2   Year                                                      13408 non-null  int64
#  3   Number of non-employing business exits                    13408 non-null  int64
#  4   Number of employing business exits: 1-4 employees         13408 non-null  int64
#  5   Number of employing business exits: 5-19 employees        13408 non-null  int64
#  6   Number of employing business exits: 20 or more employees  13408 non-null  int64
#  7   Total number of business exits                            13408 non-null  int64
# dtypes: int64(6), object(2)
# memory usage: 838.1+ KB
# None
# Number of businesses by industry - at 30 June
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16979 entries, 0 to 16978
# Data columns (total 23 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Code                                                   16979 non-null  object
#  1   Region                                                 16979 non-null  object
#  2   Year                                                   16979 non-null  int64
#  3   Agriculture, forestry and fishing (no.)                16979 non-null  int64
#  4   Mining (no.)                                           16979 non-null  int64
#  5   Manufacturing (no.)                                    16979 non-null  int64
#  6   Electricity, gas, water and waste services (no.)       16979 non-null  int64
#  7   Construction (no.)                                     16979 non-null  int64
#  8   Wholesale trade (no.)                                  16979 non-null  int64
#  9   Retail trade (no.)                                     16979 non-null  int64
#  10  Accommodation and food services (no.)                  16979 non-null  int64
#  11  Transport, postal and warehousing (no.)                16979 non-null  int64
#  12  Information media and telecommunications (no.)         16979 non-null  int64
#  13  Financial and insurance services (no.)                 16979 non-null  int64
#  14  Rental, hiring and real estate services (no.)          16979 non-null  int64
#  15  Professional, scientific and technical services (no.)  16979 non-null  int64
#  16  Administrative and support services (no.)              16979 non-null  int64
#  17  Public administration and safety (no.)                 16979 non-null  int64
#  18  Education and training (no.)                           16979 non-null  int64
#  19  Health care and social assistance (no.)                16979 non-null  int64
#  20  Arts and recreation services (no.)                     16979 non-null  int64
#  21  Other services (no.)                                   16979 non-null  int64
#  22  Currently unknown (no.)                                16979 non-null  int64
# dtypes: int64(21), object(2)
# memory usage: 3.0+ MB
# None
# Number of businesses by turnover - at 30 June
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16980 entries, 0 to 16979
# Data columns (total 9 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Code                                                           16980 non-null  object
#  1   Region                                                         16980 non-null  object
#  2   Year                                                           16980 non-null  int64
#  3   Number of businesses with turnover of zero to less than $50k   16980 non-null  int64
#  4   Number of businesses with turnover of $50k to less than $200k  16980 non-null  int64
#  5   Number of businesses with turnover of $200k to less than $2m   16980 non-null  int64
#  6   Number of businesses with turnover of $2m to less than $5m     16980 non-null  int64
#  7   Number of businesses with turnover of $5m to less than $10m    16980 non-null  int64
#  8   Number of businesses with turnover of $10m or more             16980 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 1.2+ MB
# None
# Business entries by turnover - year ended 30 June
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13381 entries, 0 to 13380
# Data columns (total 9 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Code                                                                 13381 non-null  object
#  1   Region                                                               13381 non-null  object
#  2   Year                                                                 13381 non-null  int64
#  3   Number of business entries with turnover of zero to less than $50k   13381 non-null  int64
#  4   Number of business entries with turnover of $50k to less than $200k  13381 non-null  int64
#  5   Number of business entries with turnover of $200k to less than $2m   13381 non-null  int64
#  6   Number of business entries with turnover of $2m to less than $5m     13381 non-null  int64
#  7   Number of business entries with turnover of $5m to less than $10m    13381 non-null  int64
#  8   Number of business entries with turnover of $10m or more             13381 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 941.0+ KB
# None
# Business exits by turnover - year ended 30 June
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13354 entries, 0 to 13353
# Data columns (total 9 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   Code                                                               13354 non-null  object
#  1   Region                                                             13354 non-null  object
#  2   Year                                                               13354 non-null  int64
#  3   Number of business exits with turnover of zero to less than $50k   13354 non-null  int64
#  4   Number of business exits with turnover of $50k to less than $200k  13354 non-null  int64
#  5   Number of business exits with turnover of $200k to less than $2m   13354 non-null  int64
#  6   Number of business exits with turnover of $2m to less than $5m     13354 non-null  int64
#  7   Number of business exits with turnover of $5m to less than $10m    13354 non-null  int64
#  8   Number of business exits with turnover of $10m or more             13354 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 939.1+ KB
# None
# Building approvals - year ended 30 June
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18919 entries, 0 to 18918
# Data columns (total 13 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Code                                                     18919 non-null  object
#  1   Region                                                   18919 non-null  object
#  2   Year                                                     18919 non-null  int64
#  3   Private sector houses (no.)                              18919 non-null  int64
#  4   Private sector dwellings excluding houses (no.)          18919 non-null  int64
#  5   Total private sector dwelling units (no.)                18919 non-null  int64
#  6   Total dwelling units (no.)                               18919 non-null  int64
#  7   Value of private sector houses ($m)                      18919 non-null  float64
#  8   Value of private sector dwellings excluding houses ($m)  18919 non-null  float64
#  9   Total value of private sector dwelling units ($m)        18919 non-null  float64
#  10  Value of residential building ($m)                       18919 non-null  float64
#  11  Value of non-residential building ($m)                   18919 non-null  float64
#  12  Value of total building ($m)                             18919 non-null  float64
# dtypes: float64(6), int64(5), object(2)
# memory usage: 1.9+ MB
# None
# Residential property transfers - year ended 30 June
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19425 entries, 0 to 19424
# Data columns (total 7 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Code                                             19425 non-null  object
#  1   Region                                           19425 non-null  object
#  2   Year                                             19425 non-null  int64
#  3   Number of established house transfers (no.)      19425 non-null  int64
#  4   Median price of established house transfers ($)  19425 non-null  float64
#  5   Number of attached dwelling transfers (no.)      19425 non-null  int64
#  6   Median price of attached dwelling transfers ($)  19425 non-null  float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 1.0+ MB
# None
# Debtors entering personal insolvencies - year ended 30 June
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5130 entries, 0 to 5129
# Data columns (total 6 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   Code                                                               5130 non-null   object
#  1   Region                                                             5130 non-null   object
#  2   Year                                                               5130 non-null   int64
#  3   Debtors entering business related personal insolvencies (no.)      5130 non-null   int64
#  4   Debtors entering non-business related personal insolvencies (no.)  5130 non-null   int64
#  5   Total debtors entering personal insolvencies (no.)                 5130 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 240.6+ KB
# None
# Occupations of debtors entering personal insolvencies - year ended 30 June
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4683 entries, 0 to 4682
# Data columns (total 12 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Code                                             4683 non-null   object
#  1   Region                                           4683 non-null   object
#  2   Year                                             4683 non-null   int64
#  3   Managers (no.)                                   4683 non-null   int64
#  4   Professionals (no.)                              4683 non-null   int64
#  5   Technicians and trades workers (no.)             4683 non-null   int64
#  6   Community and personal service workers (no.)     4683 non-null   int64
#  7   Clerical and administrative workers (no.)        4683 non-null   int64
#  8   Sales workers (no.)                              4683 non-null   int64
#  9   Machinery operators and drivers (no.)            4683 non-null   int64
#  10  Labourers (no.)                                  4683 non-null   int64
#  11  Debtors with other or unknown occupations (no.)  4683 non-null   int64
# dtypes: int64(10), object(2)
# memory usage: 439.2+ KB
# None
# Agricultural commodities - year ended 30 June
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1882 entries, 0 to 1881
# Data columns (total 12 columns):
#  #   Column                                                                             Non-Null Count  Dtype
# ---  ------                                                                             --------------  -----
#  0   Code                                                                               1882 non-null   object
#  1   Region                                                                             1882 non-null   object
#  2   Year                                                                               1882 non-null   int64
#  3   Area of holding - total area (ha)                                                  1882 non-null   float64
#  4   Dairy cattle - total (no.)                                                         1882 non-null   int64
#  5   Meat cattle - total (no.)                                                          1882 non-null   int64
#  6   Sheep and lambs - total (no.)                                                      1882 non-null   int64
#  7   Pigs - total (no.)                                                                 1882 non-null   int64
#  8   Meat chickens - total (no.)                                                        1882 non-null   int64
#  9   Broadacre crops - total area (ha)                                                  1882 non-null   float64
#  10  Vegetables - total area (ha)                                                       1882 non-null   float64
#  11  Orchard fruit trees and nut trees (produce intended for sale) - total area - (ha)  1882 non-null   float64
# dtypes: float64(4), int64(6), object(2)
# memory usage: 176.6+ KB
# None
# Gross value of agricultural production - year ended 30 June
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1696 entries, 0 to 1695
# Data columns (total 6 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Code                                                                1696 non-null   object
#  1   Region                                                              1696 non-null   object
#  2   Year                                                                1696 non-null   int64
#  3   Agricultural production - total gross value ($m)                    1696 non-null   float64
#  4   Crops - total gross value ($m)                                      1696 non-null   float64
#  5   Livestock slaughtered and other disposals - total gross value ($m)  1696 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 79.6+ KB
# None
# Industry of employment - Persons aged 15 years and over - Census
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10179 entries, 0 to 10178
# Data columns (total 24 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Code                                                             10179 non-null  object
#  1   Region                                                           10179 non-null  object
#  2   Year                                                             10179 non-null  int64
#  3   Agriculture, forestry and fishing (%)                            10179 non-null  float64
#  4   Mining (%)                                                       10179 non-null  float64
#  5   Manufacturing (%)                                                10179 non-null  float64
#  6   Electricity, gas, water and waste services (%)                   10179 non-null  float64
#  7   Construction (%)                                                 10179 non-null  float64
#  8   Wholesale trade (%)                                              10179 non-null  float64
#  9   Retail trade (%)                                                 10179 non-null  float64
#  10  Accommodation and food services (%)                              10179 non-null  float64
#  11  Transport, postal and warehousing (%)                            10179 non-null  float64
#  12  Information media and telecommunications (%)                     10179 non-null  float64
#  13  Financial and insurance services (%)                             10179 non-null  float64
#  14  Rental, hiring and real estate services (%)                      10179 non-null  float64
#  15  Professional, scientific and technical services (%)              10179 non-null  float64
#  16  Administrative and support services (%)                          10179 non-null  float64
#  17  Public administration and safety (%)                             10179 non-null  float64
#  18  Education and training (%)                                       10179 non-null  float64
#  19  Health care and social assistance (%)                            10179 non-null  float64
#  20  Arts and recreation services (%)                                 10179 non-null  float64
#  21  Other services (%)                                               10179 non-null  float64
#  22  Industry of employment inadequately described or not stated (%)  10179 non-null  float64
#  23  Total persons employed aged 15 years and over (no.)              10179 non-null  int64
# dtypes: float64(20), int64(2), object(2)
# memory usage: 1.9+ MB
# None
# Estimated dwelling stock - as at June quarter
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17089 entries, 0 to 17088
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Code                            17089 non-null  object
#  1   Region                          17089 non-null  object
#  2   Year                            17089 non-null  int64
#  3   Houses - additions (no.)        17089 non-null  int64
#  4   Houses - removals (no.)         17089 non-null  int64
#  5   Houses - total (no.)            17089 non-null  int64
#  6   Townhouses - additions (no.)    17089 non-null  int64
#  7   Townhouses - removals (no.)     17089 non-null  int64
#  8   Townhouses - total (no.)        17089 non-null  int64
#  9   Apartments - additions (no.)    17089 non-null  int64
#  10  Apartments - removals (no.)     17089 non-null  int64
#  11  Apartments - total (no.)        17089 non-null  int64
#  12  Total dwelling additions (no.)  17089 non-null  int64
#  13  Total dwelling removals (no.)   17089 non-null  int64
#  14  Total dwellings (no.)           17089 non-null  int64
# dtypes: int64(13), object(2)
# memory usage: 2.0+ MB
# None
# Power Station location
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Project Name  365 non-null    object
#  1   State         365 non-null    object
#  2   MW Capacity   365 non-null    float64
#  3   Fuel Source   365 non-null    object
#  4   status        365 non-null    object
#  5   latitude      365 non-null    float64
#  6   longitude     365 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 20.1+ KB
# None
# Other energy sources
# <class 'pandas.core.frame.DataFrame'>
# Index: 4877 entries, 0 to 5940
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Reporting entity                 4476 non-null   category
#  1   Facility name                    4877 non-null   category
#  2   Type                             4877 non-null   category
#  3   State                            4877 non-null   category
#  4   Electricity production GJ        4877 non-null   float64
#  5   Electricity production MWh       4877 non-null   float64
#  6   Total scope 1 emissions t CO2 e  4877 non-null   float64
#  7   Total scope 2 emissions t CO2 e  4877 non-null   float64
#  8   Total emissions t CO2 e          4877 non-null   int64
#  9   Emission intensity t CO2 e MWh   4877 non-null   float64
#  10  Grid connected                   4877 non-null   category
#  11  Grid                             4877 non-null   category
#  12  Primary fuel                     4877 non-null   category
# dtypes: category(7), float64(5), int64(1)
# memory usage: 360.6 KB
# None

# %%
sub_tables
